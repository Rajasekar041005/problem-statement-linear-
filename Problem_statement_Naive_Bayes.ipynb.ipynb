# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB,MultinomialNB

# %%
df=pd.read_csv("/content/cars_fuel_efficiency_clean.csv")
df
# Out:
#      trip_id       car_name vehicle_type fuel_type        trip_category  \
# 0          1       Lexus ES       Luxury    Diesel  Very Long (>400 km)
# 1          2       Lexus ES       Luxury    Petrol   Medium (50–200 km)
# 2          3        Audi A6       Luxury    Petrol   Medium (50–200 km)
# 3          4   Maruti Swift    Hatchback    Diesel    Long (200–400 km)
# 4          5  Hyundai Creta          SUV    Diesel    Long (200–400 km)
# ..       ...            ...          ...       ...                  ...
# 595      596     Tata Tiago    Hatchback    Diesel   Medium (50–200 km)
# 596      597     Honda Brio    Hatchback    Diesel    Long (200–400 km)
# 597      598        Audi A6       Luxury    Petrol   Medium (50–200 km)
# 598      599   Maruti Swift    Hatchback    Diesel  Very Long (>400 km)
# 599      600   Tata Harrier          SUV    Petrol   Medium (50–200 km)
#
#      distance_km  trip_duration_hr  avg_speed_kmph  base_mileage_kmpl  \
# 0         437.85              4.84           90.51              11.31
# 1         181.86              3.54           51.43               9.98
# 2         118.07              1.46           80.62              11.06
# 3         343.16              4.72           72.65              21.17
# 4         371.03              3.87           95.78              13.01
# ..           ...               ...             ...                ...
# 595       113.18              1.36           82.93              18.53
# 596       226.13              2.91           77.66              19.89
# 597        60.02              0.53          114.28               8.96
# 598       414.00              7.03           58.91              21.65
# 599       188.31              2.68           70.14              11.84
#
#      actual_mileage_kmpl  mileage_delta_kmpl  fuel_consumed_L  fuel_cost_usd  \
# 0                  11.24               -0.07            38.96          44.59
# 1                   9.61               -0.37            18.92          23.93
# 2                  11.24                0.18            10.50          13.28
# 3                  19.65               -1.52            17.46          19.98
# 4                  12.39               -0.62            29.95          34.28
# ..                   ...                 ...              ...            ...
# 595                17.05               -1.48             6.64           7.60
# 596                21.35                1.46            10.59          12.12
# 597                 8.83               -0.13             6.80           8.60
# 598                20.97               -0.68            19.74          22.59
# 599                11.76               -0.08            16.01          20.25
#
#      cost_per_km_usd  co2_emissions_kg  co2_per_km  relative_efficiency  \
# 0             0.1018           104.413      0.2385               0.5979
# 1             0.1316            43.705      0.2403               0.5113
# 2             0.1125            24.255      0.2054               0.5982
# 3             0.0582            46.793      0.1364               0.7181
# 4             0.0924            80.266      0.2163               0.5717
# ..               ...               ...         ...                  ...
# 595           0.0671            17.795      0.1572               0.6227
# 596           0.0536            28.381      0.1255               0.7801
# 597           0.1433            15.708      0.2617               0.4696
# 598           0.0546            52.903      0.1278               0.7662
# 599           0.1075            36.983      0.1964               0.5428
#
#     efficiency_band
# 0           Average
# 1              Poor
# 2           Average
# 3           Average
# 4           Average
# ..              ...
# 595         Average
# 596            Good
# 597            Poor
# 598            Good
# 599            Poor
#
# [600 rows x 18 columns]

# %%
x=df.drop(['efficiency_band','trip_id','car_name'],axis=1)
y=df['efficiency_band']

# %%
x=pd.get_dummies(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
model.predict(x_test)
# Out:
# array(['Poor', 'Good', 'Good', 'Average', 'Average', 'Good', 'Average',
#        'Poor', 'Average', 'Good', 'Average', 'Average', 'Average',
#        'Average', 'Good', 'Average', 'Excellent', 'Average', 'Average',
#        'Good', 'Good', 'Poor', 'Poor', 'Average', 'Average', 'Average',
#        'Average', 'Good', 'Average', 'Poor', 'Excellent', 'Excellent',
#        'Average', 'Poor', 'Average', 'Poor', 'Average', 'Poor', 'Good',
#        'Excellent', 'Poor', 'Excellent', 'Excellent', 'Average',
#        'Average', 'Excellent', 'Average', 'Poor', 'Average', 'Average',
#        'Average', 'Average', 'Average', 'Poor', 'Poor', 'Excellent',
#        'Average', 'Poor', 'Good', 'Good', 'Good', 'Good', 'Average',
#        'Excellent', 'Poor', 'Good', 'Good', 'Average', 'Poor', 'Poor',
#        'Average', 'Poor', 'Good', 'Poor', 'Good', 'Good', 'Poor', 'Good',
#        'Average', 'Average', 'Average', 'Excellent', 'Good', 'Average',
#        'Good', 'Poor', 'Poor', 'Poor', 'Good', 'Average', 'Good',
#        'Average', 'Good', 'Poor', 'Average', 'Excellent', 'Poor',
#        'Average', 'Good', 'Average', 'Average', 'Average', 'Poor', 'Poor',
#        'Average', 'Poor', 'Average', 'Average', 'Average', 'Poor',
#        'Average', 'Good', 'Good', 'Average', 'Poor', 'Average',
#        'Excellent', 'Excellent', 'Average', 'Average'], dtype='<U9')

# %%
model.score(x_test,y_test)
# Out:
# 0.675

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

model = MultinomialNB()
model.fit(x_train_scaled, y_train)
# Out:
# MultinomialNB()

# %%
model.score(x_test,y_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MultinomialNB was fitted without feature names
#   warnings.warn(
# 0.55
